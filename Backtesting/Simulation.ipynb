# %%
import matplotlib.pyplot as plt
import pandas as pd
#algo to test
from test_algo import Trader

from datamodel import *

import time as chronos

class Simulation:
    def __init__(self):
        # Simulation data
        self.position = {}
        self.my_trades = {}
        self.market_trades = {}
        self.observations = {}
        self.resting_orders = {}

        # Trader's cash values
        self.cash = 0
        self.historical_cash = list()

        # Initial values for the time and the state
        self.prev_time = -1
        self.state = TradingState(-1, {}, {}, {}, {}, {}, {})

        # Simulation's position limit
        self.position_limit = 20

    def process_order(self, order: Order, is_resting_order: bool = False):
        # Get the product name
        product = order.symbol

        # Get order levels, { Price: Quantity }
        levels = self.state.order_depths[order.symbol]

        if order.quantity < 0:
            # Sell/Ask order - Need corresponding buy
            volume = abs(order.quantity)


            while len(levels.buy_orders):
                # Get the best bid (Highest buy price)
                best_bid = max(levels.buy_orders.keys())

                # Break if the best bid does not match the order price
                if best_bid < order.price: break

                # The amount that is exchanged (Buy orders are positive)
                taken_volume = min(volume, abs(levels.buy_orders[best_bid]))

                # If it is resting order and the position is invalid
                # after making order, then drop the order for now
                if is_resting_order and abs(self.position[product] - taken_volume) > self.position_limit: continue
                
                # Update volumes and position by taken_volume
                volume -= taken_volume
                levels.buy_orders[best_bid] -= taken_volume
                self.position[product] -= taken_volume

                # Update cash (Selling so cash increases by volume sold)
                self.cash += best_bid * taken_volume

                # Add the trade to completed trades
                self.my_trades[product].append(Trade(product, best_bid, taken_volume, None, "self", self.prev_time))

                # Break if volume left is 0
                if volume <= 0: break

                # Delist the buy order if it is fulfilled
                if levels.buy_orders[best_bid] <= 0: del levels.buy_orders[best_bid]


            # Add a resting order if the trader's order is not fulfilled
            if volume > 0:
                resting_order = Order(product, order.price, -volume)
                self.resting_orders[product].append(resting_order)
                print(f"Resting order added: {resting_order}")

        else:
            # Buy/Bid order - Need corresponding sell
            volume = abs(order.quantity)


            while len(levels.sell_orders):
                # Get the best ask (Lowest sell price)
                best_ask = min(levels.sell_orders.keys())

                # Break if the best ask does not match the order price
                if best_ask > order.price: break

                # The amount that is exchanged (Sell orders are negative)
                taken_volume = min(volume, abs(levels.sell_orders[best_ask]))

                # If it is resting order and the position is invalid
                # after making order, then drop the order for now
                if is_resting_order and abs(self.position[product] + taken_volume) > self.position_limit: continue

                # Update volumes and position by taken_volume
                volume -= taken_volume
                levels.sell_orders[best_ask] += taken_volume
                self.position[product] += taken_volume

                # Update cash (Buying so cash decreases by volume bought)
                self.cash -= best_ask * taken_volume

                # Add the trade to completed trades
                self.my_trades[product].append(Trade(product, best_ask, taken_volume, "self", None, self.prev_time))

                # Break if volume left is 0
                if volume <= 0: break

                # Delist the sell order if it is fulfilled
                if abs(levels.sell_orders[best_ask]) <= 0: del levels.sell_orders[best_ask]


            # Add a resting order if the trader's order is not fulfilled
            if volume > 0:
                resting_order = Order(product, order.price, volume)
                self.resting_orders[product].append(resting_order)
                print(f"Resting order added: {resting_order}")

    def simulate(self, rnd: int, day: int, trader: Trader):
        # The file path for the prices and trades of the selected round
        folder = '../Data_analysis'
        prices_path = f"{folder}/island-data-bottle-round-{rnd}/prices_round_{rnd}_day_{day}.csv"
        trades_path = f"{folder}/island-data-bottle-round-{rnd}/trades_round_{rnd}_day_{day}_nn.csv"

        # Data frames for each csv
        df_prices = pd.read_csv(prices_path, sep=';')
        df_trades = pd.read_csv(trades_path, sep=';')


        # Iterate through each row of the data frame
        for _, row in df_prices.iterrows():
            # The current time and product being traded
            time = row["timestamp"]
            product = row["product"]

            # Initialize product's data
            if product not in self.position:
                self.position[product] = 0
                self.my_trades[product] = []
                self.market_trades[product] = []

            # Default listing
            listing = {product: {"symbol": product, "product": product, "denomination": product}}

            # Setup order depth
            depth = {product: OrderDepth()}
            for i in range(1, 4):
                if row[f"bid_price_{i}"] > 0: depth[product].buy_orders [row[f"bid_price_{i}"]] = row[f"bid_volume_{i}"]
                if row[f"ask_price_{i}"] > 0: depth[product].sell_orders[row[f"ask_price_{i}"]] = -row[f"ask_volume_{i}"]

            # Get all trades that happened at this time
            trades = df_trades[df_trades['timestamp'] == time]

            # Process each of those trades
            for _, trade in trades.iterrows():
                # Get the product that is being traded
                symbol = trade['symbol']

                # Skip any trades that aren't for our product
                if symbol != product: continue

                # Create a new trade object and add it to market_trades
                t = Trade(symbol, trade['price'], trade['quantity'], trade['buyer'], trade['seller'], time)
                self.market_trades[product].append(t)

            # If time has elapsed
            if time != self.prev_time and self.prev_time != -1:

                # Update the current state's timestamp
                self.state.timestamp = time

                # Act on our trader's actions at this time
                output = trader.run(self.state)

                # Loop through each product
                for product in output:

                    # Process our trader's orders
                    for order in output[product]:
                        self.process_order(order)
                    output[product] = []

                    # Process and reset resting orders
                    output[product].extend(self.resting_orders[product]);
                    self.resting_orders[product] = [];

                    for order in output[product]:
                        self.process_order(order, True);
                    output[product] = []

                # Update the trading state
                self.state = TradingState(time, listing, depth, self.my_trades, self.market_trades, self.position, self.observations)

            else:
                # Before trading starts, initialize trading state's listings and order_depths
                self.state.listings[product] = listing[product]
                self.state.order_depths[product] = depth[product]

                # Also initialize resting orders
                self.resting_orders[product] = []


            # Complain if the position limit is violated
            for product in self.position:
                if abs(self.position[product]) > self.position_limit:
                    print(f"Position limit for {product} violated - {self.position[product]}")
                    raise RuntimeError()

            # Update historical_cash
            self.historical_cash.append(self.cash)

            # Update prev_time
            self.prev_time = time

        # Output trader's end cash
        print(f"You ended with: {self.cash} seashells")

        # Plot trader's cash over time
        plt.plot(df_prices["timestamp"], self.historical_cash)
        plt.show()





if __name__ == '__main__':
    simulation = Simulation();
    simulation.simulate(1, 0, Trader())
# Out:
# Spread: 7 MM BUY PEARLS 10.0x 9999 position: 0 MM SELL PEARLS 10.0x 10004 position: 0
# 6
# MM BUY BANANAS 5.0x 4894 position: 0
# MM SELL BANANAS 5.0x 4898 position: 0
# Resting order added: (PEARLS, 9999, 10.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 10.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (BANANAS, 4894, 5.0)
# Resting order added: (BANANAS, 4898, -5.0)
# Resting order added: (BANANAS, 4894, 5.0)
# Resting order added: (BANANAS, 4898, -5.0)
# Spread: 6 MM BUY PEARLS 10.0x 9997 position: 0 MM SELL PEARLS 10.0x 10001 position: 0
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10001, -10.0)
# Resting order added: (PEARLS, 9999, 10.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10001, -10.0)
# Spread: 8 MM BUY PEARLS 10.0x 9997 position: 0 MM SELL PEARLS 10.0x 10003 position: 0
# 7
# MM BUY BANANAS 5.0x 4893 position: 0
# MM SELL BANANAS 5.0x 4898 position: 0
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 10.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10001, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (BANANAS, 4893, 5.0)
# Resting order added: (BANANAS, 4898, -5.0)
# Resting order added: (BANANAS, 4893, 5.0)
# Resting order added: (BANANAS, 4898, -5.0)
# BUY PEARLS 3x 9998 position: 3
# 6
# MM BUY BANANAS 5.0x 4894 position: 0
# MM SELL BANANAS 5.0x 4898 position: 0
# Resting order added: (PEARLS, 9999, 10.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10001, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (BANANAS, 4894, 5.0)
# Resting order added: (BANANAS, 4898, -5.0)
# Resting order added: (BANANAS, 4894, 5.0)
# Resting order added: (BANANAS, 4898, -5.0)
# Spread: 6 MM BUY PEARLS 8.0x 9999 position: 3 MM SELL PEARLS 11.0x 10003 position: 3
# 5
# MM BUY BANANAS 5.0x 4895 position: 0
# MM SELL BANANAS 5.0x 4898 position: 0
# Resting order added: (PEARLS, 9999, 8.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9999, 10.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10001, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 8.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (BANANAS, 4895, 5.0)
# Resting order added: (BANANAS, 4898, -5.0)
# Resting order added: (BANANAS, 4895, 5.0)
# Resting order added: (BANANAS, 4898, -5.0)
# SELL PEARLS 1x 10002 position: 2
# 6
# MM BUY BANANAS 5.0x 4894 position: 0
# MM SELL BANANAS 5.0x 4898 position: 0
# Resting order added: (PEARLS, 9999, 10.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10001, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 8.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (BANANAS, 4894, 5.0)
# Resting order added: (BANANAS, 4898, -5.0)
# Resting order added: (BANANAS, 4894, 5.0)
# Resting order added: (BANANAS, 4898, -5.0)
# Spread: 6 MM BUY PEARLS 9.0x 9997 position: 2 MM SELL PEARLS 11.0x 10001 position: 2
# 5
# MM BUY BANANAS 5.0x 4893 position: 0
# MM SELL BANANAS 5.0x 4896 position: 0
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10001, -11.0)
# Resting order added: (PEARLS, 9999, 10.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10001, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 8.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10001, -11.0)
# Resting order added: (BANANAS, 4893, 5.0)
# Resting order added: (BANANAS, 4896, -5.0)
# Resting order added: (BANANAS, 4893, 5.0)
# Resting order added: (BANANAS, 4896, -5.0)
# Spread: 7 MM BUY PEARLS 9.0x 9999 position: 2 MM SELL PEARLS 11.0x 10004 position: 2
# 6
# MM BUY BANANAS 5.0x 4893 position: 0
# MM SELL BANANAS 5.0x 4897 position: 0
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -11.0)
# Resting order added: (PEARLS, 9999, 10.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10001, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 8.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10001, -11.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -11.0)
# Resting order added: (BANANAS, 4893, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# Resting order added: (BANANAS, 4893, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# Spread: 10 MM BUY PEARLS 9.0x 9996 position: 2 MM SELL PEARLS 11.0x 10004 position: 2
# 7
# MM BUY BANANAS 5.0x 4892 position: 0
# MM SELL BANANAS 5.0x 4897 position: 0
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -11.0)
# Resting order added: (PEARLS, 9999, 10.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10001, -10.0)
# Resting order added: (PEARLS, 9997, 10.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 8.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10001, -11.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -11.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -11.0)
# Resting order added: (BANANAS, 4892, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# Resting order added: (BANANAS, 4892, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# 6
# MM BUY BANANAS 5.0x 4893 position: 0
# MM SELL BANANAS 5.0x 4897 position: 0
# Spread: 8 MM BUY PEARLS 9.0x 9997 position: 2 MM SELL PEARLS 11.0x 10003 position: 2
# Resting order added: (BANANAS, 4893, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# Resting order added: (BANANAS, 4892, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# Resting order added: (BANANAS, 4893, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Spread: 8 MM BUY PEARLS 9.0x 9997 position: 2 MM SELL PEARLS 11.0x 10003 position: 2
# 6
# MM BUY BANANAS 5.0x 4892 position: 0
# MM SELL BANANAS 5.0x 4896 position: 0
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (BANANAS, 4892, 5.0)
# Resting order added: (BANANAS, 4896, -5.0)
# Resting order added: (BANANAS, 4892, 5.0)
# Resting order added: (BANANAS, 4896, -5.0)
# 7
# MM BUY BANANAS 5.0x 4892 position: 0
# MM SELL BANANAS 5.0x 4897 position: 0
# Spread: 8 MM BUY PEARLS 9.0x 9997 position: 2 MM SELL PEARLS 11.0x 10003 position: 2
# Resting order added: (BANANAS, 4892, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# Resting order added: (BANANAS, 4892, 5.0)
# Resting order added: (BANANAS, 4896, -5.0)
# Resting order added: (BANANAS, 4892, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Spread: 6 MM BUY PEARLS 9.0x 9999 position: 2 MM SELL PEARLS 11.0x 10003 position: 2
# 6
# MM BUY BANANAS 5.0x 4893 position: 0
# MM SELL BANANAS 5.0x 4897 position: 0
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (BANANAS, 4893, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# Resting order added: (BANANAS, 4893, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# BUY BANANAS 4x 4892
# Spread: 8 MM BUY PEARLS 9.0x 9997 position: 2 MM SELL PEARLS 11.0x 10003 position: 2
# Resting order added: (BANANAS, 4893, 5.0)
# Resting order added: (BANANAS, 4897, -5.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Spread: 8 MM BUY PEARLS 9.0x 9997 position: 2 MM SELL PEARLS 11.0x 10003 position: 2
# 6
# MM BUY BANANAS 11.0x 4892 position: 4
# MM SELL BANANAS 19.0x 4896 position: 4
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -11.0)
# Resting order added: (BANANAS, 4892, 11.0)
# Resting order added: (BANANAS, 4896, -19.0)
# Resting order added: (BANANAS, 4892, 11.0)
# Resting order added: (BANANAS, 4896, -19.0)
# SELL BANANAS 1x 4896
# SELL PEARLS 1x 10002 position: 1
# Resting order added: (BANANAS, 4892, 11.0)
# Resting order added: (BANANAS, 4896, -19.0)
# Spread: 8 MM BUY PEARLS 9.0x 9997 position: 1 MM SELL PEARLS 10.0x 10003 position: 1
# 6
# MM BUY BANANAS 12.0x 4892 position: 3
# MM SELL BANANAS 18.0x 4896 position: 3
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (BANANAS, 4892, 12.0)
# Resting order added: (BANANAS, 4896, -18.0)
# Resting order added: (BANANAS, 4892, 12.0)
# Resting order added: (BANANAS, 4896, -18.0)
# BUY BANANAS 2x 4893
# Spread: 10 MM BUY PEARLS 9.0x 9996 position: 1 MM SELL PEARLS 10.0x 10004 position: 1
# Resting order added: (BANANAS, 4892, 12.0)
# Resting order added: (BANANAS, 4896, -18.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Spread: 8 MM BUY PEARLS 9.0x 9997 position: 1 MM SELL PEARLS 10.0x 10003 position: 1
# 6
# MM BUY BANANAS 10.0x 4892 position: 5
# MM SELL BANANAS 20.0x 4896 position: 5
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (BANANAS, 4892, 10.0)
# Resting order added: (BANANAS, 4896, -20.0)
# Resting order added: (BANANAS, 4892, 10.0)
# Resting order added: (BANANAS, 4896, -20.0)
# 7
# MM BUY BANANAS 10.0x 4891 position: 5
# MM SELL BANANAS 20.0x 4896 position: 5
# Spread: 8 MM BUY PEARLS 9.0x 9997 position: 1 MM SELL PEARLS 10.0x 10003 position: 1
# Resting order added: (BANANAS, 4891, 10.0)
# Resting order added: (BANANAS, 4896, -20.0)
# Resting order added: (BANANAS, 4892, 10.0)
# Resting order added: (BANANAS, 4896, -20.0)
# Resting order added: (BANANAS, 4891, 10.0)
# Resting order added: (BANANAS, 4896, -20.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Spread: 6 MM BUY PEARLS 9.0x 9997 position: 1 MM SELL PEARLS 10.0x 10001 position: 1
# 5
# MM BUY BANANAS 10.0x 4891 position: 5
# MM SELL BANANAS 20.0x 4894 position: 5
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10001, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10001, -10.0)
# Resting order added: (BANANAS, 4891, 10.0)
# Resting order added: (BANANAS, 4894, -20.0)
# Resting order added: (BANANAS, 4891, 10.0)
# Resting order added: (BANANAS, 4894, -20.0)
# 7
# MM BUY BANANAS 10.0x 4891 position: 5
# MM SELL BANANAS 20.0x 4896 position: 5
# Spread: 10 MM BUY PEARLS 9.0x 9996 position: 1 MM SELL PEARLS 10.0x 10004 position: 1
# Resting order added: (BANANAS, 4891, 10.0)
# Resting order added: (BANANAS, 4896, -20.0)
# Resting order added: (BANANAS, 4891, 10.0)
# Resting order added: (BANANAS, 4894, -20.0)
# Resting order added: (BANANAS, 4891, 10.0)
# Resting order added: (BANANAS, 4896, -20.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Spread: 8 MM BUY PEARLS 9.0x 9997 position: 1 MM SELL PEARLS 10.0x 10003 position: 1
# 6
# MM BUY BANANAS 10.0x 4891 position: 5
# MM SELL BANANAS 20.0x 4895 position: 5
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (BANANAS, 4891, 10.0)
# Resting order added: (BANANAS, 4895, -20.0)
# Resting order added: (BANANAS, 4891, 10.0)
# Resting order added: (BANANAS, 4895, -20.0)
# Spread: 8 MM BUY PEARLS 9.0x 9997 position: 1 MM SELL PEARLS 10.0x 10003 position: 1
# 6
# MM BUY BANANAS 10.0x 4891 position: 5
# MM SELL BANANAS 20.0x 4895 position: 5
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (BANANAS, 4891, 10.0)
# Resting order added: (BANANAS, 4895, -20.0)
# Resting order added: (BANANAS, 4891, 10.0)
# Resting order added: (BANANAS, 4895, -20.0)
# Spread: 6 MM BUY PEARLS 9.0x 9999 position: 1 MM SELL PEARLS 10.0x 10003 position: 1
# SELL BANANAS 3x 4894
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Spread: 8 MM BUY PEARLS 9.0x 9997 position: 1 MM SELL PEARLS 10.0x 10003 position: 1
# BUY BANANAS 5x 4891
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Spread: 10 MM BUY PEARLS 9.0x 9996 position: 1 MM SELL PEARLS 10.0x 10004 position: 1
# 7
# MM BUY BANANAS 8.0x 4890 position: 7
# MM SELL BANANAS 22.0x 4895 position: 7
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (BANANAS, 4890, 8.0)
# Resting order added: (BANANAS, 4895, -22.0)
# Resting order added: (BANANAS, 4890, 8.0)
# Resting order added: (BANANAS, 4895, -22.0)
# Spread: 6 MM BUY PEARLS 9.0x 9999 position: 1 MM SELL PEARLS 10.0x 10003 position: 1
# 6
# MM BUY BANANAS 8.0x 4891 position: 7
# MM SELL BANANAS 22.0x 4895 position: 7
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (BANANAS, 4891, 8.0)
# Resting order added: (BANANAS, 4895, -22.0)
# Resting order added: (BANANAS, 4891, 8.0)
# Resting order added: (BANANAS, 4895, -22.0)
# Spread: 7 MM BUY PEARLS 9.0x 9999 position: 1 MM SELL PEARLS 10.0x 10004 position: 1
# SELL BANANAS 1x 4895
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# SELL PEARLS 10x 10002 position: -9
# 6
# MM BUY BANANAS 9.0x 4892 position: 6
# MM SELL BANANAS 21.0x 4896 position: 6
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4896, -21.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4896, -21.0)
# Spread: 8 MM BUY PEARLS 14.0x 9997 position: -9 MM SELL PEARLS 5.0x 10003 position: -9
# 6
# MM BUY BANANAS 9.0x 4892 position: 6
# MM SELL BANANAS 21.0x 4896 position: 6
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4896, -21.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4896, -21.0)
# Spread: 8 MM BUY PEARLS 14.0x 9997 position: -9 MM SELL PEARLS 5.0x 10003 position: -9
# 6
# MM BUY BANANAS 9.0x 4892 position: 6
# MM SELL BANANAS 21.0x 4896 position: 6
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4896, -21.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4896, -21.0)
# Spread: 6 MM BUY PEARLS 14.0x 9997 position: -9 MM SELL PEARLS 5.0x 10001 position: -9
# 5
# MM BUY BANANAS 9.0x 4892 position: 6
# MM SELL BANANAS 21.0x 4895 position: 6
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4895, -21.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4895, -21.0)
# Spread: 8 MM BUY PEARLS 14.0x 9997 position: -9 MM SELL PEARLS 5.0x 10003 position: -9
# 6
# MM BUY BANANAS 9.0x 4892 position: 6
# MM SELL BANANAS 21.0x 4896 position: 6
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4896, -21.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4896, -21.0)
# Spread: 8 MM BUY PEARLS 14.0x 9997 position: -9 MM SELL PEARLS 5.0x 10003 position: -9
# 6
# MM BUY BANANAS 9.0x 4892 position: 6
# MM SELL BANANAS 21.0x 4896 position: 6
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4896, -21.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4896, -21.0)
# Spread: 6 MM BUY PEARLS 14.0x 9997 position: -9 MM SELL PEARLS 5.0x 10001 position: -9
# 5
# MM BUY BANANAS 9.0x 4892 position: 6
# MM SELL BANANAS 21.0x 4895 position: 6
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4895, -21.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4895, -21.0)
# BUY PEARLS 1x 9998 position: -8
# 7
# MM BUY BANANAS 9.0x 4892 position: 6
# MM SELL BANANAS 21.0x 4897 position: 6
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4897, -21.0)
# Resting order added: (BANANAS, 4892, 9.0)
# Resting order added: (BANANAS, 4897, -21.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# SELL PEARLS 1x 10002 position: -9
# 6
# MM BUY BANANAS 9.0x 4893 position: 6
# MM SELL BANANAS 21.0x 4897 position: 6
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (BANANAS, 4893, 9.0)
# Resting order added: (BANANAS, 4897, -21.0)
# Resting order added: (BANANAS, 4893, 9.0)
# Resting order added: (BANANAS, 4897, -21.0)
# Spread: 7 MM BUY PEARLS 14.0x 9999 position: -9 MM SELL PEARLS 5.0x 10004 position: -9
# 5
# MM BUY BANANAS 9.0x 4894 position: 6
# MM SELL BANANAS 21.0x 4897 position: 6
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (BANANAS, 4894, 9.0)
# Resting order added: (BANANAS, 4897, -21.0)
# Resting order added: (BANANAS, 4894, 9.0)
# Resting order added: (BANANAS, 4897, -21.0)
# SELL PEARLS 9x 10002 position: -18
# 6
# MM BUY BANANAS 9.0x 4893 position: 6
# MM SELL BANANAS 21.0x 4897 position: 6
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (BANANAS, 4893, 9.0)
# Resting order added: (BANANAS, 4897, -21.0)
# Resting order added: (BANANAS, 4893, 9.0)
# Resting order added: (BANANAS, 4897, -21.0)
# Spread: 8 MM BUY PEARLS 19.0x 9997 position: -18 MM SELL PEARLS 0.0x 10003 position: -18
# 7
# MM BUY BANANAS 9.0x 4893 position: 6
# MM SELL BANANAS 21.0x 4898 position: 6
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (BANANAS, 4893, 9.0)
# Resting order added: (BANANAS, 4898, -21.0)
# Resting order added: (BANANAS, 4893, 9.0)
# Resting order added: (BANANAS, 4898, -21.0)
# Spread: 8 MM BUY PEARLS 19.0x 9997 position: -18 MM SELL PEARLS 0.0x 10003 position: -18
# BUY BANANAS 10x 4893
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Spread: 8 MM BUY PEARLS 19.0x 9997 position: -18 MM SELL PEARLS 0.0x 10003 position: -18
# 7
# MM BUY BANANAS 1.0x 4893 position: 16
# MM SELL BANANAS 31.0x 4898 position: 16
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (BANANAS, 4893, 1.0)
# Resting order added: (BANANAS, 4898, -31.0)
# Resting order added: (BANANAS, 4893, 1.0)
# Resting order added: (BANANAS, 4898, -31.0)
# BUY PEARLS 1x 9998 position: -17
# 7
# MM BUY BANANAS 1.0x 4893 position: 16
# MM SELL BANANAS 31.0x 4898 position: 16
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (BANANAS, 4893, 1.0)
# Resting order added: (BANANAS, 4898, -31.0)
# Resting order added: (BANANAS, 4893, 1.0)
# Resting order added: (BANANAS, 4898, -31.0)
# Spread: 10 MM BUY PEARLS 18.0x 9996 position: -17 MM SELL PEARLS 1.0x 10004 position: -17
# 7
# MM BUY BANANAS 1.0x 4893 position: 16
# MM SELL BANANAS 31.0x 4898 position: 16
# Resting order added: (PEARLS, 9996, 18.0)
# Resting order added: (PEARLS, 10004, -1.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9996, 18.0)
# Resting order added: (PEARLS, 10004, -1.0)
# Resting order added: (BANANAS, 4893, 1.0)
# Resting order added: (BANANAS, 4898, -31.0)
# Resting order added: (BANANAS, 4893, 1.0)
# Resting order added: (BANANAS, 4898, -31.0)
# Spread: 8 MM BUY PEARLS 18.0x 9997 position: -17 MM SELL PEARLS 1.0x 10003 position: -17
# 6
# MM BUY BANANAS 1.0x 4894 position: 16
# MM SELL BANANAS 31.0x 4898 position: 16
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9996, 18.0)
# Resting order added: (PEARLS, 10004, -1.0)
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (BANANAS, 4894, 1.0)
# Resting order added: (BANANAS, 4898, -31.0)
# Resting order added: (BANANAS, 4894, 1.0)
# Resting order added: (BANANAS, 4898, -31.0)
# Spread: 6 MM BUY PEARLS 18.0x 9999 position: -17 MM SELL PEARLS 1.0x 10003 position: -17
# BUY BANANAS 4x 4893
# Resting order added: (PEARLS, 9999, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9996, 18.0)
# Resting order added: (PEARLS, 10004, -1.0)
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9999, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# SELL PEARLS 3x 10002 position: -20
# SELL BANANAS 1x 4898
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9996, 18.0)
# Resting order added: (PEARLS, 10004, -1.0)
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9999, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# BUY PEARLS 4x 9998 position: -16
# 6
# MM BUY BANANAS 4.0x 4894 position: 19
# MM SELL BANANAS 34.0x 4898 position: 19
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9996, 18.0)
# Resting order added: (PEARLS, 10004, -1.0)
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9999, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (BANANAS, 4894, 4.0)
# Resting order added: (BANANAS, 4898, -34.0)
# Resting order added: (BANANAS, 4894, 4.0)
# Resting order added: (BANANAS, 4898, -34.0)
# Spread: 6 MM BUY PEARLS 18.0x 9999 position: -16 MM SELL PEARLS 1.0x 10003 position: -16
# 6
# MM BUY BANANAS 4.0x 4894 position: 19
# MM SELL BANANAS 34.0x 4898 position: 19
# Resting order added: (PEARLS, 9999, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9996, 18.0)
# Resting order added: (PEARLS, 10004, -1.0)
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9999, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9999, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (BANANAS, 4894, 4.0)
# Resting order added: (BANANAS, 4898, -34.0)
# Resting order added: (BANANAS, 4894, 4.0)
# Resting order added: (BANANAS, 4898, -34.0)
# SELL PEARLS 1x 10002 position: -17
# 5
# MM BUY BANANAS 4.0x 4895 position: 19
# MM SELL BANANAS 34.0x 4898 position: 19
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9996, 18.0)
# Resting order added: (PEARLS, 10004, -1.0)
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9999, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9999, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (BANANAS, 4895, 4.0)
# Resting order added: (BANANAS, 4898, -34.0)
# Resting order added: (BANANAS, 4895, 4.0)
# Resting order added: (BANANAS, 4898, -34.0)
# Spread: 8 MM BUY PEARLS 18.0x 9997 position: -17 MM SELL PEARLS 1.0x 10003 position: -17
# 7
# MM BUY BANANAS 4.0x 4894 position: 19
# MM SELL BANANAS 34.0x 4899 position: 19
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9997, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9996, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10003, -10.0)
# Resting order added: (PEARLS, 9999, 9.0)
# Resting order added: (PEARLS, 10004, -10.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10003, -5.0)
# Resting order added: (PEARLS, 9997, 14.0)
# Resting order added: (PEARLS, 10001, -5.0)
# Resting order added: (PEARLS, 9999, 14.0)
# Resting order added: (PEARLS, 10004, -5.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9997, 19.0)
# Resting order added: (PEARLS, 9996, 18.0)
# Resting order added: (PEARLS, 10004, -1.0)
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9999, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9999, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (BANANAS, 4894, 4.0)
# Resting order added: (BANANAS, 4899, -34.0)
# Resting order added: (BANANAS, 4894, 4.0)
# Resting order added: (BANANAS, 4899, -34.0)
# 7
# MM BUY BANANAS 4.0x 4894 position: 19
# MM SELL BANANAS 34.0x 4899 position: 19
# Spread: 10 MM BUY PEARLS 18.0x 9996 position: -17 MM SELL PEARLS 1.0x 10004 position: -17
# Resting order added: (BANANAS, 4894, 4.0)
# Resting order added: (BANANAS, 4899, -34.0)
# Resting order added: (BANANAS, 4894, 4.0)
# Resting order added: (BANANAS, 4899, -34.0)
# Resting order added: (BANANAS, 4894, 4.0)
# Resting order added: (BANANAS, 4899, -34.0)
# Resting order added: (PEARLS, 9996, 18.0)
# Resting order added: (PEARLS, 10004, -1.0)
# Resting order added: (PEARLS, 9996, 18.0)
# Resting order added: (PEARLS, 10004, -1.0)
# 5
# MM BUY BANANAS 4.0x 4895 position: 19
# MM SELL BANANAS 34.0x 4898 position: 19
# Resting order added: (BANANAS, 4895, 4.0)
# Resting order added: (BANANAS, 4898, -34.0)
# Resting order added: (BANANAS, 4894, 4.0)
# Resting order added: (BANANAS, 4899, -34.0)
# Resting order added: (BANANAS, 4894, 4.0)
# Resting order added: (BANANAS, 4899, -34.0)
# Resting order added: (BANANAS, 4895, 4.0)
# Resting order added: (BANANAS, 4898, -34.0)
# Spread: 8 MM BUY PEARLS 18.0x 9997 position: -17 MM SELL PEARLS 1.0x 10003 position: -17
# 6
# MM BUY BANANAS 4.0x 4896 position: 19
# MM SELL BANANAS 34.0x 4900 position: 19
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (BANANAS, 4896, 4.0)
# Resting order added: (BANANAS, 4900, -34.0)
# Resting order added: (BANANAS, 4896, 4.0)
# Resting order added: (BANANAS, 4900, -34.0)
# SELL PEARLS 1x 10002 position: -18
# 5
# MM BUY BANANAS 4.0x 4897 position: 19
# MM SELL BANANAS 34.0x 4900 position: 19
# Resting order added: (PEARLS, 9997, 18.0)
# Resting order added: (PEARLS, 10003, -1.0)
# Resting order added: (BANANAS, 4897, 4.0)
# Resting order added: (BANANAS, 4900, -34.0)
# Resting order added: (BANANAS, 4897, 4.0)
# Resting order added: (BANANAS, 4900, -34.0)
# Spread: 6 MM BUY PEARLS 19.0x 9999 position: -18 MM SELL PEARLS 0.0x 10003 position: -18
# Resting order added: (BANANAS, 4897, 4.0)
# Resting order added: (BANANAS, 4900, -34.0)
# Resting order added: (PEARLS, 9999, 19.0)
# Resting order added: (PEARLS, 9999, 19.0)
# SELL BANANAS 1x 4900
# SELL PEARLS 1x 10002 position: -19
# Resting order added: (BANANAS, 4897, 4.0)
# Resting order added: (BANANAS, 4900, -34.0)
# 6
# MM BUY BANANAS 3.0x 4896 position: 18
# MM SELL BANANAS 33.0x 4900 position: 18
# Resting order added: (BANANAS, 4896, 3.0)
# Resting order added: (BANANAS, 4900, -33.0)
# Resting order added: (BANANAS, 4896, 3.0)
# Resting order added: (BANANAS, 4900, -33.0)
# BUY PEARLS 4x 9998 position: -15
# 6
# MM BUY BANANAS 3.0x 4896 position: 18
# MM SELL BANANAS 33.0x 4900 position: 18
# Resting order added: (BANANAS, 4896, 3.0)
# Resting order added: (BANANAS, 4900, -33.0)
# Resting order added: (BANANAS, 4896, 3.0)
# Resting order added: (BANANAS, 4900, -33.0)
# Resting order added: (BANANAS, 4896, 3.0)
# Resting order added: (BANANAS, 4900, -33.0)
# BUY BANANAS 2x 4895
# Spread: 8 MM BUY PEARLS 17.0x 9997 position: -15 MM SELL PEARLS 2.0x 10003 position: -15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4964\1571236013.py in <module>
#     231 if __name__ == '__main__':
#     232     simulation = Simulation();
# --> 233     simulation.simulate(1, 0, Trader())
#
# ~\AppData\Local\Temp\ipykernel_4964\1571236013.py in simulate(self, rnd, day, trader)
#     191
#     192                     for order in output[product]:
# --> 193                         self.process_order(order, True);
#     194                     output[product] = []
#     195
#
# ~\AppData\Local\Temp\ipykernel_4964\1571236013.py in process_order(self, order, is_resting_order)
#      96                 # If it is resting order and the position is invalid
#      97                 # after making order, then drop the order for now
# ---> 98                 if is_resting_order and abs(self.position[product] + taken_volume) > self.position_limit: continue
#      99
#     100                 # Update volumes and position by taken_volume
#
# KeyboardInterrupt:
